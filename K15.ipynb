# %% [markdown]
# ## Introduction
# Greetings from the Kaggle bot! This is an automatically-generated kernel with starter code demonstrating how to read in the data and begin exploring. Click the blue "Edit Notebook" or "Fork Notebook" button at the top of this kernel to begin editing.

# %% [markdown]
# ## Exploratory Analysis
# To begin this exploratory analysis, first use `matplotlib` to import libraries and define functions for plotting the data. Depending on the data, not all plots will be made. (Hey, I'm just a kerneling bot, not a Kaggle Competitions Grandmaster!)

# %%
import matplotlib.pyplot as plt # plotting
import numpy as np # linear algebra
import os # accessing directory structure
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %% [markdown]
# There are 10 csv files in the current version of the dataset:

# %%
print(os.listdir('input'))
# Out:
# ['392-crypto-currency-pairs-at-minute-resolution', 'ecommerce-behavior-data-from-multi-category-store', 'nyc-parking-tickets', 'Questions.csv', 'Answers.csv', 'Tags.csv', '2010.csv', '2011.csv', '2009.csv', '2017-07_bme280sof.csv', '2017-07_sds011sof.csv', '2017-08_bme280sof.csv', '2017-08_sds011sof.csv', '2017-09_bme280sof.csv', '2017-09_sds011sof.csv', '2017-10_bme280sof.csv', '2017-10_sds011sof.csv', '2017-11_bme280sof.csv', '2017-11_sds011sof.csv', '2017-12_bme280sof.csv', '2017-12_sds011sof.csv', '2018-01_bme280sof.csv', '2018-01_sds011sof.csv', '2018-02_bme280sof.csv', '2018-02_sds011sof.csv', '2018-03_bme280sof.csv', '2018-03_sds011sof.csv', '2018-04_bme280sof.csv', '2018-04_sds011sof.csv', '2018-05_bme280sof.csv', '2018-05_sds011sof.csv', '2018-06_bme280sof.csv', '2018-06_sds011sof.csv', '2018-07_bme280sof.csv', '2018-07_sds011sof.csv', '2018-08_bme280sof.csv', '2018-08_sds011sof.csv', '2018-09_bme280sof.csv', '2018-09_sds011sof.csv', '2018-10_bme280sof.csv', '2018-10_sds011s
# ...

# %% [markdown]
# The next hidden code cells define functions for plotting data. Click on the "Code" button in the published kernel to reveal the hidden code.

# %%
# Distribution graphs (histogram/bar graph) of column data
def plotPerColumnDistribution(df, nGraphShown, nGraphPerRow):
    nunique = df.nunique()
    df = df[[col for col in df if nunique[col] > 1 and nunique[col] < 50]] # For displaying purposes, pick columns that have between 1 and 50 unique values
    nRow, nCol = df.shape
    columnNames = list(df)
    nGraphRow = (nCol + nGraphPerRow - 1) / nGraphPerRow
    plt.figure(num = None, figsize = (6 * nGraphPerRow, 8 * nGraphRow), dpi = 80, facecolor = 'w', edgecolor = 'k')
    for i in range(min(nCol, nGraphShown)):
        plt.subplot(nGraphRow, nGraphPerRow, i + 1)
        columnDf = df.iloc[:, i]
        if (not np.issubdtype(type(columnDf.iloc[0]), np.number)):
            valueCounts = columnDf.value_counts()
            valueCounts.plot.bar()
        else:
            columnDf.hist()
        plt.ylabel('counts')
        plt.xticks(rotation = 90)
        plt.title(f'{columnNames[i]} (column {i})')
    plt.tight_layout(pad = 1.0, w_pad = 1.0, h_pad = 1.0)
    plt.show()

# %%
# Correlation matrix
def plotCorrelationMatrix(df, graphWidth):
    filename = df.dataframeName
    df = df.dropna('columns') # drop columns with NaN
    df = df[[col for col in df if df[col].nunique() > 1]] # keep columns where there are more than 1 unique values
    if df.shape[1] < 2:
        print(f'No correlation plots shown: The number of non-NaN or constant columns ({df.shape[1]}) is less than 2')
        return
    corr = df.corr()
    plt.figure(num=None, figsize=(graphWidth, graphWidth), dpi=80, facecolor='w', edgecolor='k')
    corrMat = plt.matshow(corr, fignum = 1)
    plt.xticks(range(len(corr.columns)), corr.columns, rotation=90)
    plt.yticks(range(len(corr.columns)), corr.columns)
    plt.gca().xaxis.tick_bottom()
    plt.colorbar(corrMat)
    plt.title(f'Correlation Matrix for {filename}', fontsize=15)
    plt.show()

# %%
# Scatter and density plots
def plotScatterMatrix(df, plotSize, textSize):
    df = df.select_dtypes(include =[np.number]) # keep only numerical columns
    # Remove rows and columns that would lead to df being singular
    df = df.dropna('columns')
    df = df[[col for col in df if df[col].nunique() > 1]] # keep columns where there are more than 1 unique values
    columnNames = list(df)
    if len(columnNames) > 10: # reduce the number of columns for matrix inversion of kernel density plots
        columnNames = columnNames[:10]
    df = df[columnNames]
    ax = pd.plotting.scatter_matrix(df, alpha=0.75, figsize=[plotSize, plotSize], diagonal='kde')
    corrs = df.corr().values
    for i, j in zip(*plt.np.triu_indices_from(ax, k = 1)):
        ax[i, j].annotate('Corr. coef = %.3f' % corrs[i, j], (0.8, 0.2), xycoords='axes fraction', ha='center', va='center', size=textSize)
    plt.suptitle('Scatter and Density Plot')
    plt.show()

# %% [markdown]
# Now you're ready to read in the data and use the plotting functions to visualize the data.

# %% [markdown]
# ### Let's check 1st file: ../input/2009.csv

# %%
nRowsRead = None # specify 'None' if want to read whole file
# 2009.csv has 6429338 rows in reality, but we are only loading/previewing the first 1000 rows
df1 = pd.read_csv('input/2009.csv', delimiter=',', nrows = nRowsRead)
df1.dataframeName = '2009.csv'
nRow, nCol = df1.shape
print(f'There are {nRow} rows and {nCol} columns')
# Out:
# Canceled future for execute_request message before replies were done
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# Let's take a quick look at what the data looks like:

# %%
df1.head(5)
# Out:
#       FL_DATE OP_CARRIER  OP_CARRIER_FL_NUM ORIGIN DEST  CRS_DEP_TIME  \
# 0  2009-01-01         XE               1204    DCA  EWR          1100
# 1  2009-01-01         XE               1206    EWR  IAD          1510
# 2  2009-01-01         XE               1207    EWR  DCA          1100
# 3  2009-01-01         XE               1208    DCA  EWR          1240
# 4  2009-01-01         XE               1209    IAD  EWR          1715
#
#    DEP_TIME  DEP_DELAY  TAXI_OUT  WHEELS_OFF  ...  CRS_ELAPSED_TIME  \
# 0    1058.0       -2.0      18.0      1116.0  ...              62.0
# 1    1509.0       -1.0      28.0      1537.0  ...              82.0
# 2    1059.0       -1.0      20.0      1119.0  ...              70.0
# 3    1249.0        9.0      10.0      1259.0  ...              77.0
# 4    1705.0      -10.0      24.0      1729.0  ...             105.0
#
#    ACTUAL_ELAPSED_TIME  AIR_TIME  DISTANCE  CARRIER_DELAY  WEATHER_DELAY  \
# ...

# %% [markdown]
# Distribution graphs (histogram/bar graph) of sampled columns:

# %%
# Modified from original: Commenting the below line as it gives an erorr.
# plotPerColumnDistribution(df1, 10, 5)

# %% [markdown]
# Correlation matrix:

# %%
plotCorrelationMatrix(df1, 8)
# Out:
# /tmp/ipykernel_869440/128494285.py:4: FutureWarning: In a future version of pandas all arguments of DataFrame.dropna will be keyword-only.
#   df = df.dropna('columns') # drop columns with NaN

# %% [markdown]
# Scatter and density plots:

# %%
plotScatterMatrix(df1, 20, 10)
# Out:
# /tmp/ipykernel_869440/950191735.py:5: FutureWarning: In a future version of pandas all arguments of DataFrame.dropna will be keyword-only.
#   df = df.dropna('columns')

# %% [markdown]
# ### Let's check 2nd file: ../input/2010.csv

# %%
nRowsRead = None # specify 'None' if want to read whole file
# 2010.csv has 6450117 rows in reality, but we are only loading/previewing the first 1000 rows
df2 = pd.read_csv('input/2010.csv', delimiter=',', nrows = nRowsRead)
df2.dataframeName = '2010.csv'
nRow, nCol = df2.shape
print(f'There are {nRow} rows and {nCol} columns')
# Out:
# There are 1000 rows and 28 columns

# %% [markdown]
# Let's take a quick look at what the data looks like:

# %%
df2.head(5)
# Out:
#       FL_DATE OP_CARRIER  OP_CARRIER_FL_NUM ORIGIN DEST  CRS_DEP_TIME  \
# 0  2010-01-01         MQ               4438    LGA  RDU          1940
# 1  2010-01-01         MQ               4440    DCA  JFK           950
# 2  2010-01-01         MQ               4443    LGA  RDU           900
# 3  2010-01-01         MQ               4445    RDU  LGA          1940
# 4  2010-01-01         MQ               4447    JFK  DCA          2035
#
#    DEP_TIME  DEP_DELAY  TAXI_OUT  WHEELS_OFF  ...  CRS_ELAPSED_TIME  \
# 0    2101.0       81.0      14.0      2115.0  ...             110.0
# 1     949.0       -1.0      13.0      1002.0  ...              70.0
# 2     937.0       37.0      11.0       948.0  ...             120.0
# 3    1935.0       -5.0      12.0      1947.0  ...             100.0
# 4    2236.0      121.0      18.0      2254.0  ...              85.0
#
#    ACTUAL_ELAPSED_TIME  AIR_TIME  DISTANCE  CARRIER_DELAY  WEATHER_DELAY  \
# ...

# %% [markdown]
# Distribution graphs (histogram/bar graph) of sampled columns:

# %%
# Modified from original: Commenting the below line as it gives an erorr.
# plotPerColumnDistribution(df2, 10, 5)

# %% [markdown]
# Correlation matrix:

# %%
plotCorrelationMatrix(df2, 8)
# Out:
# /tmp/ipykernel_869440/128494285.py:4: FutureWarning: In a future version of pandas all arguments of DataFrame.dropna will be keyword-only.
#   df = df.dropna('columns') # drop columns with NaN

# %% [markdown]
# Scatter and density plots:

# %%
plotScatterMatrix(df2, 20, 10)
# Out:
# /tmp/ipykernel_869440/950191735.py:5: FutureWarning: In a future version of pandas all arguments of DataFrame.dropna will be keyword-only.
#   df = df.dropna('columns')

# %% [markdown]
# ### Let's check 3rd file: ../input/2011.csv

# %%
nRowsRead = None # specify 'None' if want to read whole file
# 2011.csv has 6066650 rows in reality, but we are only loading/previewing the first 1000 rows
df3 = pd.read_csv('input/2011.csv', delimiter=',', nrows = nRowsRead)
df3.dataframeName = '2011.csv'
nRow, nCol = df3.shape
print(f'There are {nRow} rows and {nCol} columns')
# Out:
# There are 1000 rows and 28 columns

# %% [markdown]
# Let's take a quick look at what the data looks like:

# %%
df3.head(5)
# Out:
#       FL_DATE OP_CARRIER  OP_CARRIER_FL_NUM ORIGIN DEST  CRS_DEP_TIME  \
# 0  2011-01-01         MQ               4529    BOS  JFK          1830
# 1  2011-01-01         MQ               4532    BNA  DCA          1100
# 2  2011-01-01         MQ               4532    DCA  JFK          1400
# 3  2011-01-01         MQ               4537    RDU  JFK          1710
# 4  2011-01-01         MQ               4540    CMH  LGA          1340
#
#    DEP_TIME  DEP_DELAY  TAXI_OUT  WHEELS_OFF  ...  CRS_ELAPSED_TIME  \
# 0    1823.0       -7.0      68.0      1931.0  ...              90.0
# 1    1052.0       -8.0      11.0      1103.0  ...              95.0
# 2    1358.0       -2.0       9.0      1407.0  ...              79.0
# 3    1706.0       -4.0      59.0      1805.0  ...             105.0
# 4    1340.0        0.0      14.0      1354.0  ...             105.0
#
#    ACTUAL_ELAPSED_TIME  AIR_TIME  DISTANCE  CARRIER_DELAY  WEATHER_DELAY  \
# ...

# %% [markdown]
# Distribution graphs (histogram/bar graph) of sampled columns:

# %%
# Modified from original: Commenting the below line as it gives an erorr.
# plotPerColumnDistribution(df3, 10, 5)

# %% [markdown]
# Correlation matrix:

# %%
plotCorrelationMatrix(df3, 8)
# Out:
# /tmp/ipykernel_869440/128494285.py:4: FutureWarning: In a future version of pandas all arguments of DataFrame.dropna will be keyword-only.
#   df = df.dropna('columns') # drop columns with NaN

# %% [markdown]
# Scatter and density plots:

# %%
plotScatterMatrix(df3, 20, 10)
# Out:
# /tmp/ipykernel_869440/950191735.py:5: FutureWarning: In a future version of pandas all arguments of DataFrame.dropna will be keyword-only.
#   df = df.dropna('columns')

# %% [markdown]
# ## Conclusion
# This concludes your starter analysis! To go forward from here, click the blue "Edit Notebook" button at the top of the kernel. This will create a copy of the code and environment for you to edit. Delete, modify, and add code as you please. Happy Kaggling!
