# %% [markdown]
# <div>
#     <img src='https://storage.googleapis.com/kaggle-datasets-images/340483/674955/c74e20b41b2cdacf6915881df995a5d8/dataset-cover.png'/>
# </div>

# %%
import numpy as np
import pandas as pd
import time
start_time = time.time()

# %%
path = 'input/2017-07_bme280sof.csv'
df = pd.read_csv(path)
df = df[['pressure','temperature','humidity']]
df.head()
# Out:
#    pressure  temperature  humidity
# 0  95270.27        23.46     62.48
# 1  94355.83        23.06     59.46
# 2  95155.81        26.53     44.38
# 3  94679.57        28.34     38.28
# 4  94327.88        26.31     46.37

# %%
df_idx = pd.DataFrame({'idx':np.arange(len(df))})
df = pd.concat([df, df_idx], axis=1)
df.head()
# Out:
#    pressure  temperature  humidity  idx
# 0  95270.27        23.46     62.48    0
# 1  94355.83        23.06     59.46    1
# 2  95155.81        26.53     44.38    2
# 3  94679.57        28.34     38.28    3
# 4  94327.88        26.31     46.37    4

# %%
# use the humidity as labels
# low humidity < 30
# middle humidity > 30, < 70
# highi humidity > 70

low_index = df[df['humidity'] <= 30].index
mid_index = df[(df['humidity'] > 30)&(df['humidity'] < 70)].index
high_index = df[df['humidity'] >= 70].index

# %%
df.loc[low_index, 'humidity'] = 0
df.loc[mid_index, 'humidity'] = 1
df.loc[high_index, 'humidity'] = 2
df['humidity'] = df['humidity'].astype(int)

# %%
end_time=time.time()
print(f"Total time: {end_time - start_time} s")
# Out:
# Total time: 2.910083055496216 s
